# %% [markdown]
# # Test Notebook: $MFT Parsing and UsnJrnl Enrichment
#
# ## Objective
# Parse $MFT to extract MACE timestamps and join with UsnJrnl data to enable timestamp discrepancy detection (Oh et al.'s core heuristic).
#
# ## Approach
# 1. Parse $MFT using analyzeMFT to extract file metadata
# 2. Load existing UsnJrnl.csv from Oh et al.'s tool
# 3. Join on FileReferenceNumber to add MACE timestamps
# 4. Verify timestamp discrepancy detection works
#
# --

# %%
## Cell 1: Setup and Imports
import pandas as pd
import subprocess
import os
from pathlib import Path
from datetime import datetime

# Base paths
BASE_DIR = Path('/Users/soni/Github/Digital-Detectives_Thesis')
TEST_DATASET = 'LoneWolf'  # Using LoneWolf dataset for validation

# Input paths
RAW_MFT_PATH = BASE_DIR / f'data/validation/mft/{TEST_DATASET}-MFT'
USNJRNL_CSV_PATH = BASE_DIR / f'data/validation/usnjrnl/{TEST_DATASET}-UsnJrnl.csv'

# Output paths
MFT_OUTPUT_PATH = BASE_DIR / f'data/validation/processed/phase 0.5/{TEST_DATASET}_MFT.csv'
ENRICHED_USNJRNL_PATH = BASE_DIR / f'data/validation/processed/phase 0.5/{TEST_DATASET}_UsnJrnl_enriched.csv'

# Create output directory
os.makedirs(MFT_OUTPUT_PATH.parent, exist_ok=True)

print(f"Raw $MFT: {RAW_MFT_PATH}")
print(f"Existing UsnJrnl CSV: {USNJRNL_CSV_PATH}")
print(f"Output MFT CSV: {MFT_OUTPUT_PATH}")
print(f"Output Enriched UsnJrnl: {ENRICHED_USNJRNL_PATH}")
# Out:
# Raw $MFT: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/mft/LoneWolf-MFT
# Existing UsnJrnl CSV: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/usnjrnl/LoneWolf-UsnJrnl.csv
# Output MFT CSV: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/processed/phase 0.5/LoneWolf_MFT.csv
# Output Enriched UsnJrnl: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/processed/phase 0.5/LoneWolf_UsnJrnl_enriched.csv

# %% [markdown]
# # Cell 2: Parse $MFT Using analyzeMFT
# analyzeMFT is a Python tool that parses raw $MFT files and extracts file metadata including MACE timestamps, FileReferenceNumber, and file paths.

# %%
# Cell 2: Parse $MFT using analyzeMFT (async version)
import analyzeMFT
import sys
import asyncio

print("Parsing $MFT...")

async def parse_mft():
    # Set up command-line arguments for analyzeMFT
    original_argv = sys.argv.copy()
    
    try:
        sys.argv = [
            'analyzeMFT',
            '-f', str(RAW_MFT_PATH),
            '-o', str(MFT_OUTPUT_PATH),
            '--csv'
        ]
        
        # Await the async CLI main function
        await analyzeMFT.cli_main()
        
        print(f"Successfully parsed $MFT to {MFT_OUTPUT_PATH}")
        
    except Exception as e:
        print(f"Error parsing $MFT: {e}")
        import traceback
        traceback.print_exc()
    finally:
        # Restore original argv
        sys.argv = original_argv

# Run the async function
await parse_mft()

# Verify output file was created
import os
if os.path.exists(MFT_OUTPUT_PATH):
    file_size = os.path.getsize(MFT_OUTPUT_PATH)
    print(f"MFT CSV created: {file_size:,} bytes")
else:
    print(f"Warning: Output file not created at {MFT_OUTPUT_PATH}")
# Out:
# 2025-12-30 00:43:20 - analyzeMFT.validators - WARNING - Output file already exists and will be overwritten: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/processed/phase 0.5/LoneWolf_MFT.csv
# Parsing $MFT...
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=688, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=536, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=632, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=656, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=552, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=536, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=128, length=536, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 24838176 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 458752 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 524288 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 906494464 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 16896250 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 230: Attribute length 67181312 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 326: Attribute length 2228608 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 326: Attribute length 65536 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 5701784 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 331: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 721048 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 334: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 1179800 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 349: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 327768 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 524288 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 906494464 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 16896250 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 400: Attribute length 67181312 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=552, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 262176 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 458752 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 524288 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 906494464 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 16896250 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 407: Attribute length 67181312 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 530: Attribute length 6488144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 530: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 547: Attribute length 196680 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 547: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 131560 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 65536 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 1696604720 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 1030188649 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 539113517 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 1869373796 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 577987961 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 1885435708 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 604: Attribute length 1769171318 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record
exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 998: Attribute length 1953720690 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 998: Attribute length 1999584266 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 998: Attribute length 1769369458 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 998: Attribute length 1684500073 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=128, length=520, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=128, length=528, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=608, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1142: Attribute length 458832 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1142: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=632, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=752, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=656, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=672, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=528, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=608, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1245: Attribute length 524368 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1245: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=632, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=752, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=656, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=608, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=608, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=736, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=600, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=528, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1349: Attribute length 1114192 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1349: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=600, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=640, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1412: Attribute length 6422608 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1412: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=528, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=664, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1549: Attribute length 1310800 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1549: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=584, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1663: Attribute length 1507408 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1663: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 196696 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 524288 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 906494464 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 16896250 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1677: Attribute length 67181312 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=568, record_size=1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 655448 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 524288 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 906494464 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 16896250 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 1689: Attribute length 67181312 exceeds record size 1024
# 2025-12-30 00:43:21 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=552, record_size=1024
# ...
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68215: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68215: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 131224 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68710: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 196760 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68714: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 786584 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 1397042757 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 503334216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 906363392 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 2147603397 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68716: Attribute length 33673466 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68762: Attribute length 196680 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68762: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68764: Attribute length 196696 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68764: Attribute length 393216 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.validators - WARNING - Large attribute detected: type=144, length=544, record_size=1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68941: Attribute length 196680 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 68941: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 69295: Attribute length 196680 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 69295: Attribute length 262144 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 69296: Attribute length 197104 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record 69296: Attribute length 65536 exceeds record size 1024
# 2025-12-30 00:43:30 - analyzeMFT.analyzer - ERROR - Attribute validation failed at record
# %%
# Cell 3: Load and Inspect $MFT Data

# Load parsed $MFT
mft_df = pd.read_csv(MFT_OUTPUT_PATH, low_memory=False)

print(f"$MFT Records: {len(mft_df):,}")
print(f"\nColumns: {list(mft_df.columns)}")
print(f"\n$MFT Sample:")
mft_df.head()
# Out:
# $MFT Records: 147,500
#
# Columns: ['Record Number', 'Record Status', 'Record Type', 'File Type', 'Sequence Number', 'Parent Record Number', 'Parent Record Sequence Number', 'Filename', 'Filepath', 'SI Creation Time', 'SI Modification Time', 'SI Access Time', 'SI Entry Time', 'FN Creation Time', 'FN Modification Time', 'FN Access Time', 'FN Entry Time', 'Object ID', 'Birth Volume ID', 'Birth Object ID', 'Birth Domain ID', 'Has Standard Information', 'Has Attribute List', 'Has File Name', 'Has Volume Name', 'Has Volume Information', 'Has Data', 'Has Index Root', 'Has Index Allocation', 'Has Bitmap', 'Has Reparse Point', 'Has EA Information', 'Has EA', 'Has Logged Utility Stream', 'Attribute List Details', 'Security Descriptor', 'Volume Name', 'Volume Information', 'Data Attribute', 'Index Root', 'Index Allocation', 'Bitmap', 'Reparse Point', 'EA Information', 'EA', 'Logged Utility Stream', 'MD5', 'SHA256', 'SHA512', 'CRC32']
#
# $MFT Sample:
#    Record Number Record Status Record Type File Type  Sequence Number  \
# 0              0       Invalid  Not in Use      File                0
# 1              1         Valid      In Use      File                1
# 2              2         Valid      In Use      File                2
# 3              3         Valid      In Use      File                3
# 4              4         Valid      In Use      File                4
#
#    Parent Record Number  Parent Record Sequence Number  Filename  Filepath  \
# 0                     0                              0       NaN       NaN
# 1                     5                              0  $MFTMirr       NaN
# 2                     5                              0  $LogFile       NaN
# 3                     5                              0   $Volume       NaN
# 4                     5                              0  $AttrDef       NaN
#
#            SI Creation Time  ... Index Allocation Bitmap Reparse Point  \
# 0               Not defined  ...              NaN    NaN           NaN
# 1  2018-03-27T13:07:33.477Z  ...              NaN    NaN           NaN
# 2  2018-03-27T13:07:33.477Z  ...              NaN    NaN           NaN
# 3  2018-03-27T13:07:33.477Z  ...              NaN    NaN           NaN
# 4  2018-03-27T13:07:33.477Z  ...              NaN    NaN           NaN
#
#   EA Information   EA Logged Utility Stream MD5 SHA256 SHA512 CRC32
# 0            NaN  NaN                   NaN NaN    NaN    NaN   NaN
# 1            NaN  NaN                   NaN NaN    NaN    NaN   NaN
# 2            NaN  NaN                   NaN NaN    NaN    NaN   NaN
# 3            NaN  NaN                   NaN NaN    NaN    NaN   NaN
# 4            NaN  NaN                   NaN NaN    NaN    NaN   NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# # Cell 4: Extract Relevant $MFT Columns
# We need FileReferenceNumber (for joining) and MACE timestamps (for discrepancy detection).

# %%
# Cell 4: Extract Relevant $MFT Columns

# Actual columns from analyzeMFT v3.1.1:
# - Record Number: MFT record number
# - Filename: Filename
# - Filepath: Full file path  
# - SI Creation Time: $SI CreationTime
# - SI Modification Time: $SI ModifiedTime
# - SI Access Time: $SI AccessedTime
# - SI Entry Time: $SI MFTModifiedTime

# Select relevant columns and rename for clarity
mft_clean = mft_df[[
    'Record Number',
    'Filename',
    'Filepath',
    'SI Creation Time',
    'SI Modification Time',
    'SI Access Time',
    'SI Entry Time'
]].copy()

# Rename columns to match Oh et al.'s terminology
mft_clean.columns = [
    'FileReferenceNumber',
    'FileName_MFT',
    'FullPath_MFT',
    'SI_CreationTime',
    'SI_ModifiedTime',
    'SI_AccessedTime',
    'SI_MFTModifiedTime'
]

print(f"Cleaned $MFT records: {len(mft_clean):,}")
print(f"\nSample records:")
mft_clean.head(10)
# Out:
# Cleaned $MFT records: 147,500
#
# Sample records:
#    FileReferenceNumber FileName_MFT  FullPath_MFT           SI_CreationTime  \
# 0                    0          NaN           NaN               Not defined
# 1                    1     $MFTMirr           NaN  2018-03-27T13:07:33.477Z
# 2                    2     $LogFile           NaN  2018-03-27T13:07:33.477Z
# 3                    3      $Volume           NaN  2018-03-27T13:07:33.477Z
# 4                    4     $AttrDef           NaN  2018-03-27T13:07:33.477Z
# 5                    5            .           NaN  2017-09-29T08:45:11.680Z
# 6                    6      $Bitmap           NaN  2018-03-27T13:07:33.477Z
# 7                    7        $Boot           NaN  2018-03-27T13:07:33.477Z
# 8                    8     $BadClus           NaN  2018-03-27T13:07:33.477Z
# 9                    9      $Secure           NaN  2018-03-27T13:07:33.477Z
#
#             SI_ModifiedTime           SI_AccessedTime  \
# 0               Not defined               Not defined
# 1  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 2  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 3  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 4  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 5  2018-04-04T05:59:44.969Z  2018-04-04T05:59:44.969Z
# 6  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 7  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 8  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
# 9  2018-03-27T13:07:33.477Z  2018-03-27T13:07:33.477Z
#
#          SI_MFTModifiedTime
# 0               Not defined
# 1  2018-03-27T13:07:33.477Z
# 2  2018-03-27T13:07:33.477Z
# 3  2018-03-27T13:07:33.477Z
# 4  2018-03-27T13:07:33.477Z
# 5  2018-04-04T05:59:44.969Z
# 6  2018-03-27T13:07:33.477Z
# 7  2018-03-27T13:07:33.477Z
# 8  2018-03-27T13:07:33.477Z
# 9  2018-03-27T13:07:33.477Z

# %%
# Cell 5: Load UsnJrnl Data
# Load existing UsnJrnl CSV from Oh et al.'s tool
usnjrnl_df = pd.read_csv(USNJRNL_CSV_PATH)

print(f"UsnJrnl Records: {len(usnjrnl_df):,}")
print(f"\nColumns: {list(usnjrnl_df.columns)}")
print(f"\nUsnJrnl Sample:")
usnjrnl_df.head()
# Out:
# UsnJrnl Records: 352,849
#
# Columns: ['TimeStamp(UTC+8)', 'USN', 'File/Directory Name', 'FullPath', 'EventInfo', 'SourceInfo', 'FileAttribute', 'Carving Flag', 'FileReferenceNumber', 'ParentFileReferenceNumber']
#
# UsnJrnl Sample:
#         TimeStamp(UTC+8)        USN File/Directory Name  \
# 0  04/01/18 16:56:07:567  209715200  f498ac39e16a30c8_1
# 1  04/01/18 16:56:07:567  209715296  f498ac39e16a30c8_1
# 2  04/01/18 16:56:08:568  209715392          000003.log
# 3  04/01/18 16:56:08:568  209715472  3a9f2377dc054e52_0
# 4  04/01/18 16:56:08:568  209715568  3a9f2377dc054e52_0
#
#                                             FullPath  \
# 0  \Users\jcloudy\AppData\Local\Google\Chrome\Use...
# 1  \Users\jcloudy\AppData\Local\Google\Chrome\Use...
# 2  \Users\jcloudy\AppData\Local\Google\Chrome\Use...
# 3  \Users\jcloudy\AppData\Local\Google\Chrome\Use...
# 4  \Users\jcloudy\AppData\Local\Google\Chrome\Use...
#
#                                            EventInfo SourceInfo FileAttribute  \
# 0     Data_Added / Data_Overwritten / Data_Truncated     Normal       Archive
# 1  Data_Added / Data_Overwritten / Data_Truncated...     Normal       Archive
# 2                                         Data_Added     Normal       Archive
# 3                                       File_Created     Normal       Archive
# 4                          File_Created / Data_Added     Normal       Archive
#
#    Carving Flag FileReferenceNumber ParentFileReferenceNumber
# 0           NaN  0x0007000000022A4A        0x000200000000572F
# 1           NaN  0x0007000000022A4A        0x000200000000572F
# 2           NaN  0x0002000000005737        0x000200000000572E
# 3           NaN  0x00A900000001AF8C        0x000200000000572F
# 4           NaN  0x00A900000001AF8C        0x000200000000572F

# %% [markdown]
# # Cell 6: Prepare FileReferenceNumber for Joining
# FileReferenceNumber in UsnJrnl is in hex format (e.g., '0x000B000000022A50'), while in $MFT it's decimal. We need to extract the record number portion.

# %%
# UsnJrnl FileReferenceNumber format: 0xSSSSSSSSRRRRRRRR
# Where SSSS = sequence number, RRRRRRRR = record number (lower 48 bits)

def parse_file_ref_number(hex_ref):
    """
    Extract MFT record number from FileReferenceNumber hex string.
    Format: 0xSSSSSSSSRRRRRRRR
    Returns: Record number (decimal)
    """
    if pd.isna(hex_ref) or hex_ref == '':
        return None
    
    # Remove '0x' prefix and convert to int
    hex_value = int(hex_ref, 16)
    
    # Extract lower 48 bits (record number)
    # This matches the MFT Record Number
    record_num = hex_value & 0xFFFFFFFFFFFF
    
    return record_num

# Apply to UsnJrnl
usnjrnl_df['MFT_RecordNumber'] = usnjrnl_df['FileReferenceNumber'].apply(parse_file_ref_number)

print(f"Parsed FileReferenceNumbers: {usnjrnl_df['MFT_RecordNumber'].notna().sum():,}")
print("\nSample mappings:")
print(usnjrnl_df[['FileReferenceNumber', 'MFT_RecordNumber']].head(10))
# Out:
# Parsed FileReferenceNumbers: 352,849
#
# Sample mappings:
#   FileReferenceNumber  MFT_RecordNumber
# 0  0x0007000000022A4A            141898
# 1  0x0007000000022A4A            141898
# 2  0x0002000000005737             22327
# 3  0x00A900000001AF8C            110476
# 4  0x00A900000001AF8C            110476
# 5  0x00A900000001AF8C            110476
# 6  0x00A900000001AF8C            110476
# 7  0x000F000000022A95            141973
# 8  0x000F000000022A95            141973
# 9  0x000F000000022A95            141973

# %%
# Cell 7: Join UsnJrnl with $MFT

# Left join: Keep all UsnJrnl records, add $MFT data where available
usnjrnl_enriched = usnjrnl_df.merge(
    mft_clean,
    left_on='MFT_RecordNumber',
    right_on='FileReferenceNumber',
    how='left',
    suffixes=('_event', '_mft')
)

# Check join success rate
total_records = len(usnjrnl_enriched)
matched_records = usnjrnl_enriched['SI_CreationTime'].notna().sum()
match_rate = (matched_records / total_records) * 100

print(f"Total UsnJrnl records: {total_records:,}")
print(f"Matched with $MFT: {matched_records:,} ({match_rate:.1f}%)")
print(f"Unmatched: {total_records - matched_records:,}")

usnjrnl_enriched.head()


# Filter to only rows where filenames match
name_match = (usnjrnl_enriched['File/Directory Name'] == usnjrnl_enriched['FileName_MFT'])
usnjrnl_enriched_matched = usnjrnl_enriched[name_match].copy()

print(f"Original records: {len(usnjrnl_enriched):,}")
print(f"Name-matched records: {len(usnjrnl_enriched_matched):,}")
print(f"Dropped (mismatched): {len(usnjrnl_enriched) - len(usnjrnl_enriched_matched):,}")
# Out:
# Total UsnJrnl records: 352,849
# Matched with $MFT: 352,849 (100.0%)
# Unmatched: 0
# Original records: 352,849
# Name-matched records: 101,023
# Dropped (mismatched): 251,826

# %% [markdown]
# # Cell 8: Format Timestamps for Compatibility
#
# Parse MFT timestamps and convert to same format as UsnJrnl (no milliseconds)
# This makes them directly comparable in later phases

# %%
# Cell 8: Format Timestamps - All in UTC+8 (USING MATCHED DATA)

# IMPORTANT: Use usnjrnl_enriched_matched instead of usnjrnl_enriched
for col in ['SI_CreationTime', 'SI_ModifiedTime', 'SI_AccessedTime', 'SI_MFTModifiedTime']:
    if col in usnjrnl_enriched_matched.columns:
        # Parse as UTC
        usnjrnl_enriched_matched[f'{col}_UTC'] = pd.to_datetime(
            usnjrnl_enriched_matched[col],
            utc=True,
            errors='coerce'
        ).dt.tz_localize(None)
        
        # Convert to UTC+8 (add 8 hours)
        usnjrnl_enriched_matched[col] = usnjrnl_enriched_matched[f'{col}_UTC'] + pd.Timedelta(hours=8)
        
        # Format as MM/DD/YYYY HH:MM:SS.mmm
        usnjrnl_enriched_matched[f'{col}_Formatted'] = usnjrnl_enriched_matched[col].dt.strftime('%m/%d/%Y %H:%M:%S.%f').str[:-3]

# Parse UsnJrnl timestamp
usnjrnl_enriched_matched['EventTime'] = pd.to_datetime(
    usnjrnl_enriched_matched['TimeStamp(UTC+8)'],
    format='%m/%d/%y %H:%M:%S:%f',
    errors='coerce'
)

usnjrnl_enriched_matched['EventTime_Formatted'] = usnjrnl_enriched_matched['EventTime'].dt.strftime('%m/%d/%Y %H:%M:%S.%f').str[:-3]

print("All timestamps now in UTC+8 - using NAME-MATCHED data only")
print(f"Records with formatted timestamps: {len(usnjrnl_enriched_matched):,}")
# Out:
# All timestamps now in UTC+8 - using NAME-MATCHED data only
# Records with formatted timestamps: 101,023

# %%
# Cell 8.5: Verify timestamp formatting

print("Standardized timestamp formats (all in UTC+8):")
print(f"Total records: {len(usnjrnl_enriched_matched):,}")

print("\nColumns created:")
for col in usnjrnl_enriched_matched.columns:
    if '_Formatted' in col:
        print(f"  {col}")
# Out:
# Standardized timestamp formats (all in UTC+8):
# Total records: 101,023
#
# Columns created:
#   SI_CreationTime_Formatted
#   SI_ModifiedTime_Formatted
#   SI_AccessedTime_Formatted
#   SI_MFTModifiedTime_Formatted
#   EventTime_Formatted

# %% [markdown]
# # Cell 9: Sanity Check

# %%
# Cell 9: Sanity Check (using matched data)

creation_events = usnjrnl_enriched_matched[
    usnjrnl_enriched_matched['EventInfo'].str.contains('File_Created', na=False)
].copy()

creation_events['Time_Diff_Seconds'] = abs(
    (creation_events['SI_CreationTime'] - creation_events['EventTime']).dt.total_seconds()
)

print(f"File_Created events (name-matched only): {len(creation_events):,}")
print(f"\nTime difference statistics:")
print(creation_events['Time_Diff_Seconds'].describe())

print(f"\nExamples of close matches (diff < 60s):")
close_matches = creation_events[creation_events['Time_Diff_Seconds'] < 60].head(3)
if len(close_matches) > 0:
    print(close_matches[['File/Directory Name', 'EventTime', 'SI_CreationTime', 'Time_Diff_Seconds']].to_string())

print(f"\nExamples of large differences (diff > 1 day):")
large_diff = creation_events[creation_events['Time_Diff_Seconds'] > 86400].head(3)
if len(large_diff) > 0:
    print(large_diff[['File/Directory Name', 'EventTime', 'SI_CreationTime', 'Time_Diff_Seconds']].to_string())
# Out:
# File_Created events (name-matched only): 31,499
#
# Time difference statistics:
# count    3.149500e+04
# mean     3.815324e+06
# std      6.753162e+06
# min      0.000000e+00
# 25%      1.940000e-01
# 50%      4.138000e-01
# 75%      8.734809e+05
# max      1.046616e+08
# Name: Time_Diff_Seconds, dtype: float64
#
# Examples of close matches (diff < 60s):
#   File/Directory Name               EventTime         SI_CreationTime  Time_Diff_Seconds
# 3  3a9f2377dc054e52_0 2018-04-01 16:56:08.568 2018-04-01 16:56:08.772              0.204
# 4  3a9f2377dc054e52_0 2018-04-01 16:56:08.568 2018-04-01 16:56:08.772              0.204
# 5  3a9f2377dc054e52_0 2018-04-01 16:56:08.568 2018-04-01 16:56:08.772              0.204
#
# Examples of large differences (diff > 1 day):
#                    File/Directory Name                  EventTime         SI_CreationTime  Time_Diff_Seconds
# 283                            Install 2018-04-01 16:58:42.584200 2018-04-06 12:07:33.794        414531.2098
# 284                            Install 2018-04-01 16:58:42.584200 2018-04-06 12:07:33.794        414531.2098
# 5877  84630F0DD4E7A58674CBDDA8F570DF1D 2018-04-02 06:43:08.438000 2018-03-28 04:01:07.407        441721.0310

# %%
# Cell 10: Save Enriched UsnJrnl with Proper Formatting

# CRITICAL FIX: Rename FileReferenceNumber_event back to FileReferenceNumber
# This was renamed during merge due to suffixes parameter
if 'FileReferenceNumber_event' in usnjrnl_enriched.columns:
    usnjrnl_enriched = usnjrnl_enriched.rename(columns={'FileReferenceNumber_event': 'FileReferenceNumber'})
    print("Renamed FileReferenceNumber_event → FileReferenceNumber")

# Select output columns - keep ALL UsnJrnl columns + MFT additions
output_columns = [
    # Original UsnJrnl columns (DON'T DROP ANY)
    'TimeStamp(UTC+8)', 'USN', 'File/Directory Name', 'FullPath', 'EventInfo',
    'SourceInfo', 'FileAttribute', 'Carving Flag', 'FileReferenceNumber',  # KEEP THIS

    # Added from $MFT
    'FileName_MFT', 
    'SI_CreationTime_Formatted', 'SI_ModifiedTime_Formatted', 
    'SI_AccessedTime_Formatted', 'SI_MFTModifiedTime_Formatted',
    'EventTime_Formatted',
    'MFT_RecordNumber'
]

# Keep only columns that exist
output_columns = [col for col in output_columns if col in usnjrnl_enriched.columns]
usnjrnl_output = usnjrnl_enriched[output_columns].copy()

# Drop FullPath_MFT if it's empty
if 'FullPath_MFT' in usnjrnl_output.columns and usnjrnl_output['FullPath_MFT'].isna().all():
    usnjrnl_output = usnjrnl_output.drop(columns=['FullPath_MFT'])
    print("Dropped FullPath_MFT (empty)")

# Save to CSV
usnjrnl_output.to_csv(ENRICHED_USNJRNL_PATH, index=False)

print(f"Saved: {ENRICHED_USNJRNL_PATH}")
print(f"Records: {len(usnjrnl_output):,}")
print(f"Columns: {list(usnjrnl_output.columns)}")
print(f"\nVerify FileReferenceNumber is present: {'FileReferenceNumber' in usnjrnl_output.columns}")
print(f"\nTo view properly in Excel:")
print("  1. Open Excel → Data → From Text/CSV")
print("  2. Select all timestamp columns → Change Type → Text")
print("  Or use VS Code to view without corruption")
# Out:
# Renamed FileReferenceNumber_event → FileReferenceNumber
# Saved: /Users/soni/Github/Digital-Detectives_Thesis/data/validation/processed/phase 0.5/LoneWolf_UsnJrnl_enriched.csv
# Records: 101,023 (NAME-MATCHED ONLY)
# Columns: ['TimeStamp(UTC+8)', 'USN', 'File/Directory Name', 'FullPath', 'EventInfo', 'SourceInfo', 'FileAttribute', 'Carving Flag', 'FileReferenceNumber', 'FileName_MFT', 'SI_CreationTime_Formatted', 'SI_ModifiedTime_Formatted', 'SI_AccessedTime_Formatted', 'SI_MFTModifiedTime_Formatted', 'EventTime_Formatted', 'MFT_RecordNumber']
#
# DROPPED 251,826 mismatched records
# Kept only records where FileName_MFT = File/Directory Name

# %%
import pandas as pd

# Load the CSV
path = "/Users/soni/Github/Digital-Detectives_Thesis/data/validation/processed/phase 0.5/LoneWolf_UsnJrnl_enriched.csv"
df = pd.read_csv(path)

# Show all rows when printing
pd.set_option('display.max_rows', None)

# Count instances of each EventInfo value
event_counts = df["EventInfo"].value_counts()
print(event_counts)
# Out:
# EventInfo
# File_Created                                                                                                      11279
# File_Created / Data_Added                                                                                          7969
# Data_Added                                                                                                         7589
# File_Created / Data_Added / File_Closed                                                                            7434
# Data_Overwritten                                                                                                   6775
# Data_Overwritten / File_Closed                                                                                     6312
# Hard_Link_Changed / File_Closed                                                                                    5681
# Data_Added / Data_Truncated                                                                                        5344
# Data_Added / Data_Truncated / File_Closed                                                                          5188
# Data_Added / File_Closed                                                                                           4479
# File_Renamed_Old / Transacted_Changed                                                                              3474
# File_Created / File_Closed                                                                                         3185
# File_Closed / File_Deleted                                                                                         3159
# Data_Truncated                                                                                                     2770
# File_Renamed_New / Transacted_Changed                                                                              2746
# File_Renamed_New / Transacted_Changed / File_Closed                                                                2746
# Basic_Info_Changed                                                                                                 1988
# Basic_Info_Changed / File_Closed                                                                                   1987
# Access_Right_Changed                                                                                               1070
# Access_Right_Changed / File_Closed                                                                                 1025
# File_Closed                                                                                                         881
# Extended_Attr_Changed / File_Closed                                                                                 834
# Extended_Attr_Changed                                                                                               834
# File_Renamed_New                                                                                                    471
# File_Created / Data_Added / Data_Overwritten                                                                        467
# File_Renamed_New / File_Closed                                                                                      459
# Data_Added / Data_Overwritten                                                                                       451
# Data_Added / Data_Overwritten / Data_Truncated                                                                      436
# Data_Added / Data_Overwritten / Data_Truncated / File_Closed                                                        418
# File_Created / Data_Added / Data_Overwritten / File_Closed                                                          405
# File_Renamed_Old                                                                                                    264
# Data_Added / Data_Overwritten / File_Closed                                                                         256
# Named_Data_Stream_Added / Named_Stream_Changed                                                                      227
# Named_Stream_Changed                                                                                                227
# Named_Data_Stream_Added / Named_Stream_Changed / File_Closed                                                        216
# Data_Truncated / File_Closed                                                                                        160
# Basic_Info_Changed / Data_Overwritten                                                                               124
# Basic_Info_Changed / Data_Overwritten / File_Closed                                                                 124
# Data_Overwritten / Data_Truncated                                                                                   119
# File_Created / Basic_Info_Changed / Data_Added / Content_Indexed_Attr_Changed                                       104
# File_Created / Basic_Info_Changed / Content_Indexed_Attr_Changed                                                    104
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Content_Indexed_Attr_Changed / File_Closed       76
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Content_Indexed_Attr_Changed                     76
# File_Created / Data_Added / Data_Overwritten / Data_Truncated                                                        71
# File_Created / Data_Added / Data_Overwritten / Data_Truncated / File_Closed                                          71
# File_Created / Data_Added / Data_Truncated                                                                           61
# File_Renamed_New / Access_Right_Changed / File_Closed                                                                60
# File_Renamed_New / Access_Right_Changed                                                                              60
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / File_Closed                                      51
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten                                                    51
# Data_Overwritten / File_Renamed_New / File_Closed                                                                    49
# Data_Overwritten / File_Renamed_New                                                                                  49
# Data_Overwritten / Data_Truncated / File_Closed                                                                      46
# File_Renamed_Old / Access_Right_Changed                                                                              33
# Basic_Info_Changed / Content_Indexed_Attr_Changed                                                                    32
# Basic_Info_Changed / Content_Indexed_Attr_Changed / File_Closed                                                      32
# Basic_Info_Changed / File_Renamed_New / Access_Right_Changed / File_Closed                                           32
# Basic_Info_Changed / File_Renamed_New / Access_Right_Changed                                                         32
# File_Created / Basic_Info_Changed / Data_Added / Content_Indexed_Attr_Changed / File_Closed                          27
# Basic_Info_Changed / Data_Added / Data_Overwritten / Data_Truncated                                                  26
# Basic_Info_Changed / Data_Added / Data_Overwritten / Data_Truncated / File_Closed                                    25
# Basic_Info_Changed / Data_Added / Data_Truncated                                                                     22
# Basic_Info_Changed / Data_Truncated                                                                                  21
# Basic_Info_Changed / Data_Added / Data_Overwritten                                                                   20
# Basic_Info_Changed / Data_Added / Data_Overwritten / File_Closed                                                     20
# Object_ID_Changed                                                                                                    14
# Object_ID_Changed / File_Closed                                                                                      13
# Hard_Link_Changed / Access_Right_Changed / File_Closed                                                               12
# Basic_Info_Changed / Data_Added                                                                                      12
# Basic_Info_Changed / Data_Added / File_Closed                                                                        12
# Named_Data_Stream_Added / Access_Right_Changed / Named_Stream_Changed                                                11
# Named_Data_Stream_Added / Access_Right_Changed / Named_Stream_Changed / File_Closed                                  11
# File_Created / File_Closed / File_Deleted                                                                             8
# File_Created / Data_Added / Data_Overwritten / File_Renamed_New                                                       8
# File_Renamed_New / File_Closed / File_Deleted                                                                         7
# File_Created / Data_Added / Data_Overwritten / File_Renamed_New / File_Closed                                         7
# Data_Added / Data_Overwritten / Data_Truncated / File_Renamed_New                                                     6
# File_Created / Basic_Info_Changed / Access_Right_Changed / File_Closed                                                6
# File_Created / Basic_Info_Changed / Access_Right_Changed                                                              6
# Data_Added / Data_Overwritten / Data_Truncated / File_Renamed_New / File_Closed                                       6
# File_Created / Access_Right_Changed                                                                                   6
# File_Created / Basic_Info_Changed                                                                                     5
# File_Created / Basic_Info_Changed / Data_Added                                                                        5
# Basic_Info_Changed / Data_Added / Data_Truncated / File_Closed                                                        4
# Data_Overwritten / File_Renamed_Old                                                                                   3
# Basic_Info_Changed / Object_ID_Changed / File_Renamed_New / Access_Right_Changed / File_Closed                        3
# Basic_Info_Changed / Object_ID_Changed / File_Renamed_New / Access_Right_Changed                                      3
# Basic_Info_Changed / Data_Overwritten / Content_Indexed_Attr_Changed                                                  2
# File_Created / Compression_Changed / Data_Added / Data_Overwritten / File_Closed                                      2
# File_Created / Compression_Changed / Data_Added / Data_Overwritten                                                    2
# Basic_Info_Changed / Data_Overwritten / Content_Indexed_Attr_Changed / File_Closed                                    2
# File_Created / Data_Added / Data_Overwritten / File_Closed / File_Deleted                                             1
# File_Created / Data_Added / File_Renamed_New                                                                          1
# File_Created / Data_Added / File_Renamed_New / File_Closed                                                            1
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Data_Truncated                                    1
# Basic_Info_Changed / Data_Added / Data_Truncated / Content_Indexed_Attr_Changed / File_Closed                         1
# Basic_Info_Changed / Data_Added / Data_Truncated / Content_Indexed_Attr_Changed                                       1
# Basic_Info_Changed / Data_Truncated / Content_Indexed_Attr_Changed                                                    1
# File_Created / Data_Added / Object_ID_Changed                                                                         1
# File_Created / Data_Added / Data_Overwritten / File_Renamed_Old                                                       1
# Data_Added / Data_Overwritten / Data_Truncated / File_Renamed_Old                                                     1
# Data_Added / Data_Overwritten / File_Renamed_New / File_Closed                                                        1
# Basic_Info_Changed / Data_Added / Content_Indexed_Attr_Changed / File_Closed                                          1
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Object_ID_Changed / File_Closed                   1
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Object_ID_Changed                                 1
# File_Created / Data_Added / Data_Overwritten / Object_ID_Changed                                                      1
# File_Created / Object_ID_Changed                                                                                      1
# Basic_Info_Changed / Access_Right_Changed                                                                             1
# Basic_Info_Changed / File_Renamed_Old / Access_Right_Changed                                                          1
# Data_Added / Data_Overwritten / File_Renamed_New                                                                      1
# Basic_Info_Changed / Data_Added / Content_Indexed_Attr_Changed                                                        1
# File_Created / Data_Added / Data_Truncated / File_Renamed_New / File_Closed                                           1
# File_Created / Data_Added / Data_Truncated / File_Renamed_New                                                         1
# File_Created / Basic_Info_Changed / Data_Added / Data_Overwritten / Data_Truncated / File_Closed                      1
# Name: count, dtype: int64
